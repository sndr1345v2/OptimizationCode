# %%
class Sphere:
    MIN_VALUE = -5.12
    MAX_VALUE = 5.12
    def __init__(self):
        pass
    def fitness(self, cromosoma):
        suma = 0
        for alelo in cromosoma:
            suma += alelo**2
        return suma

# %%
#import rosenbrock
#import rastrigin
#import quartic

import numpy as np
import matplotlib.pyplot as plt

v1=np.array([])
v2=np.array([])
v3=np.array([])
v4=np.array([])
v5=np.array([])
v2d=np.array([])
v4d=np.array([])
v8d=np.array([])

def graf_2d():#Función para graficar la función de 2 dimensiones
    global v2d

    for i in range(len(v1)):
        v2d=np.append(v2d,(v1[i]+v2[i]+v3[i]+v4[i]+v5[i])/5)

    for i in range(len(v2d)):
        v2d[i]=v2d[i]*-1

    x = np.arange(0,2100,100)
    y = v2d

    plt.plot(x,y,'r')
    plt.xlabel("X",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.ylabel("Y",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #Sphere
    plt.title("Sphere de 2 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.savefig("Sphere (2d).jpg",dpi=300,bbox_inches='tight')

    #Rosenbrock
    #plt.title("Rosenbrock de 2 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rosenbrock (2d).jpg",dpi=300,bbox_inches='tight')

    #Rastrigin
    #plt.title("Rastrigin de 2 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rastrigin (2d).jpg",dpi=300,bbox_inches='tight')

    #Quartic
    #plt.title("Quartic de 2 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Quartic (2d).jpg",dpi=300,bbox_inches='tight')
    plt.show()

def graf_4d():#Función para graficar la función de 4 dimensiones
    global v4d

    for i in range(len(v1)):
        v4d=np.append(v4d,(v1[i]+v2[i]+v3[i]+v4[i]+v5[i])/5)

    for i in range(len(v4d)):
        v4d[i]=v4d[i]*-1

    x = np.arange(0,2100,100)
    y = v4d

    plt.plot(x,y,'r')
    plt.xlabel("X",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.ylabel("Y",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #Sphere
    plt.title("Sphere de 4 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.savefig("Sphere (4d).jpg",dpi=300,bbox_inches='tight')

    #Rosenbrock
    #plt.title("Rosenbrock de 4 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rosenbrock (4d).jpg",dpi=300,bbox_inches='tight')

    #Rastrigin
    #plt.title("Rastrigin de 4 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rastrigin (4d).jpg",dpi=300,bbox_inches='tight')

    #Quartic
    #plt.title("Quartic de 4 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Quartic (4d).jpg",dpi=300,bbox_inches='tight')
    plt.show()

def graf_8d():#Función para graficar la función de 8 dimensiones
    global v8d
    
    for i in range(len(v1)):
        v8d=np.append(v8d,(v1[i]+v2[i]+v3[i]+v4[i]+v5[i])/5)

    for i in range(len(v8d)):
        v8d[i]=v8d[i]*-1

    x = np.arange(0,2100,100)
    y = v8d

    plt.plot(x,y,'r')
    plt.xlabel("X",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.ylabel("Y",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #Sphere
    plt.title("Sphere de 8 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.savefig("Sphere (8d).jpg",dpi=300,bbox_inches='tight')

    #Rosenbrock
    #plt.title("Rosenbrock de 8 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rosenbrock (8d).jpg",dpi=300,bbox_inches='tight')

    #Rastrigin
    #plt.title("Rastrigin de 8 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rastrigin (8d).jpg",dpi=300,bbox_inches='tight')

    #Quartic
    #plt.title("Quartic de 8 dimensiones",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Quartic (8d).jpg",dpi=300,bbox_inches='tight')
    plt.show()

def graf_2_4_8d():#Función para graficar la figura de 2, 4 y 8 dimensiones
    x = np.arange(0,2100,100)
    y1 = v2d
    y2 = v4d
    y3 = v8d

    plt.plot(x,y1,label="2 dimensiones")
    plt.plot(x,y2,label="4 dimensiones")
    plt.plot(x,y3,label="8 dimensiones")
    plt.xlabel("X",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.ylabel("Y",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.legend()
    #Sphere
    plt.title("Sphere",fontsize=14,fontfamily="times new roman",fontweight="bold")
    plt.savefig("Sphere.jpg",dpi=300,bbox_inches='tight')

    #Rosenbrock
    #plt.title("Rosenbrock",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rosenbrock.jpg",dpi=300,bbox_inches='tight')

    #Rastrigin
    #plt.title("Rastrigin",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Rastrigin.jpg",dpi=300,bbox_inches='tight')

    #Quartic
    #plt.title("Quartic",fontsize=14,fontfamily="times new roman",fontweight="bold")
    #plt.savefig("Quartic.jpg",dpi=300,bbox_inches='tight')
    plt.show()

def main():
    d=2
    cont=0
    
    global v1
    global v2
    global v3
    global v4
    global v5
    
    for i in range(15):
        if cont == 5:
            if d == 2:
                graf_2d()

            if d == 4:
                graf_4d()

            v1=np.array([])
            v2=np.array([])
            v3=np.array([])
            v4=np.array([])
            v5=np.array([])
            cont=0
            d+=d

        print("\nNúmero de ejecución:",i+1," Total de dimensiones:",d,"\n")
        s = Sphere()
        #r = rosenbrock.Rosenbrock()
        #ras = rastrigin.Rastrigin()
        #q = quartic.Quartic()
        ag = AGC(64, d, 2000, 0.02, s, False)

        if cont == 0: #Primera iteración de n dimensiones
            v1=np.append(v1,ag.run())

        if cont == 1: #Segunda iteración de n dimensiones
            v2=np.append(v2,ag.run())
            
        if cont == 2: #Tercera iteración de n dimensiones
            v3=np.append(v3,ag.run())
            
        if cont == 3: #Cuarta iteración de n dimensiones
            v4=np.append(v4,ag.run())
            
        if cont == 4: #Quinta iteración de n dimensiones
            v5=np.append(v5,ag.run())

        cont+=1

    graf_8d()
    graf_2_4_8d()
        

if __name__ == '__main__':
    main()
# Out:
# Número de ejecución: 1  Total de dimensiones: 2
#
# Generación: 100 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 200 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 300 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 400 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 500 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 600 Mejor Histórico: [-0.58083841  0.53706154] -0.62581
# Generación: 700 Mejor Histórico: [ 0.11677903 -0.7272448 ] -0.54252
# Generación: 800 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# Generación: 900 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# Generación: 1000 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# Generación: 1100 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# Generación: 1200 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# Generación: 1300 Mejor Histórico: [0.00900631 0.22935755] -0.05269
# ...

# %%
import copy
import numpy as np

class Individuo:
    def __init__(self, alelos, cromosoma):
        self._alelos = alelos
        self._cromosoma = cromosoma
        self._fitness = 0

class AGC:
    def __init__(self, cantidad_individuos, alelos, generaciones, p, problema, maxim = True):
        self._cantidad_individuos = cantidad_individuos
        self._alelos = alelos
        self._generaciones = generaciones
        self._p = p
        self._problema = problema
        self._maxim = maxim
        self._individuos = np.array([])

    def run(self):
        v=np.array([])
        self.crearIndividuos()
        self._mejor_historico = self._individuos[0]
        generacion = 1
        while generacion <= self._generaciones:
            self.evaluaIndividuos()
            self.mejor()
            hijos = np.array([])
            while len(hijos) < len(self._individuos):
                padre1 = self.ruleta()
                padre2 = self.ruleta()
                while padre1 == padre2:
                    padre2 = self.ruleta()
                h1, h2 = self.cruza(self._individuos[padre1], self._individuos[padre2])
                hijos = np.append(hijos, [h1])
                hijos = np.append(hijos, [h2])
            self.mutacion(hijos)
            self._individuos = np.copy(hijos)

            if generacion == 1:
                v=np.append(v,self._mejor_historico._fitness)
            
            if generacion % 100 == 0:
                v=np.append(v,self._mejor_historico._fitness)
                print(f'Generación: {generacion} Mejor Histórico: \
{self._mejor_historico._cromosoma} {self._mejor_historico._fitness :.5f}')
            generacion += 1
        return v

    def crearIndividuos(self):
        rango = (self._problema.MAX_VALUE - self._problema.MIN_VALUE)
        for i in range(self._cantidad_individuos):
            valores = np.random.random(size = self._alelos)
            cromosoma = self._problema.MIN_VALUE +  valores * rango
            individuo = Individuo(self._alelos, cromosoma)
            self._individuos = np.append(self._individuos, [individuo])

    def evaluaIndividuos(self):
        for i in self._individuos:
            i._fitness = self._problema.fitness(i._cromosoma)
            if not self._maxim:
                i._fitness *= -1

    def ruleta(self):
        f_sum = np.sum([i._fitness for i in self._individuos])
        r = np.random.randint(np.abs(f_sum + 1), dtype = np.int64)
        if f_sum < 0:
            r *= -1
        k = 0
        F = self._individuos[k]._fitness
        if f_sum < 0:
            while F > r and k < len(self._individuos)-1:
                k += 1
                F += self._individuos[k]._fitness
        else:
            while F < r and k < len(self._individuos)-1:
                k += 1
                F += self._individuos[k]._fitness
        return k

    def cruza(self, i1, i2):
        h1 = copy.deepcopy(i1)
        h2 = copy.deepcopy(i2)

        s = self._alelos - 1
        punto_cruza = np.random.randint(s) + 1
        h1._cromosoma[punto_cruza:], h2._cromosoma[punto_cruza:] = h2._cromosoma[punto_cruza:], h1._cromosoma[punto_cruza:]
        return h1, h2

    def mutacion(self, hijos):
        rango = (self._problema.MAX_VALUE - self._problema.MIN_VALUE)
        for h in hijos:
            for a in range(len(h._cromosoma)):
                if np.random.rand() < self._p:
                    h._cromosoma[a] = self._problema.MIN_VALUE + np.random.random() * rango

    def mejor(self):
        for i in self._individuos:
            if i._fitness > self._mejor_historico._fitness:
                self._mejor_historico = copy.deepcopy(i)
